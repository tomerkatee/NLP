# %% [markdown]
# To begin copy this notebook to your own drive:
#
# ![image.png](data:image/png;base64,...)
#
#
# ### Submission Instructions:
# 1. **Restart the kernel** (in the menubar, select Runtime$\rightarrow$Restart runtime)
# 2. **Run all cells** (in the menubar, select Runtime$\rightarrow$Run All).
# 3. **Download the notebook** (in the menubar, select File$\rightarrow$Download .ipynb)
# 4. **Upload the downloaded notebook (.ipynb file) to your repository**.
#
# Note: To use a GPU, do the following: Runtime$\rightarrow$Change runtime type$\rightarrow$ GPU
#
# Make sure you fill in any place that says `YOUR CODE HERE`, and that no tests fail.

# %% [markdown]
# ![shakespeare](https://i.imgur.com/81YZuel.jpg)
#
# # Generating Shakespeare Using a Character-level Language Model
#
# ### From Words to Characters
# In the previous two sections we dealt with word-level language models. But looking again at section 2, there is nothing that constraints us to using _words_ as the basic elemnents in our model. The model we analyzed in section 2 could just as well be character-based - just replace "word" with "character", and you are good to go. In this notebook we will train a small character-based language model that will help us generate Shakespearean-like (emphasis on the _like_...) texts.

# %% [markdown]
# ### Question 3.a
# Can you think of an advantage a character-based language model could have over a word-based language model? And what about the other way around: can you think of an advantage a word-based language model could have over a character-based language model? (Add your answer to the final submission pdf).

# %% [markdown]
# ### Using PyTorch
#
# We'll build our language model using PyTorch. PyTorch is a [very popular](https://thegradient.pub/state-of-ml-frameworks-2019-pytorch-dominates-research-tensorflow-dominates-industry/) open-source machine learning (and deep learning) framework developed by Facebook. In short:
#
# > Pytorch is a Python-based scientific computing package targeted at two sets of audiences:
# * A replacement for NumPy to use the power of GPUs
# * A deep learning research platform that provides maximum flexibility and speed
#
# To get familiar with PyTorch, check out this [quick tutorial](https://pytorch.org/tutorials/beginner/blitz/tensor_tutorial.html). In addition, another imporant difference from numpy is that PyTorch can automatically calculate the gradients needed for backpropagation, as explained [here](https://pytorch.org/tutorials/beginner/blitz/autograd_tutorial.html).

# %% [markdown]
# ### Preparing the Data
#
# Our dataset is a plain text file. For simplicity, we turn any potential unicode characters into plain ASCII by using the `unidecode` package.

# %%
# !pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.8)

# %%
import string
import random
import re
import requests
import unidecode
url = "https://github.com/tau-nlp-course/NLP_HW2/raw/main/data/shakespeare.txt"


all_characters = string.printable
n_characters = len(all_characters)  # our vocabulary size (|V| from the handout)

dataset_as_string = unidecode.unidecode(requests.get(url).content.decode())
n_chars_in_dataset = len(dataset_as_string)
print(f'Total number of characters in our dataset: {n_chars_in_dataset}')
# Out:
# Total number of characters in our dataset: 1115394

# %% [markdown]
# To make inputs out of this big string of text, we will split it into chunks.

# %%
chunk_len = 400

def random_chunk():
    start_index = random.randint(0, n_chars_in_dataset - chunk_len)
    end_index = start_index + chunk_len + 1
    return dataset_as_string[start_index:end_index]

print(random_chunk())
# Out:
# dom and devour
# Incertain lookers on. What were more holy
# Than to rejoice the former queen is well?
# What holier than, for royalty's repair,
# For present comfort and for future good,
# To bless the bed of majesty again
# With a sweet fellow to't?
#
# PAULINA:
# There is none worthy,
# Respecting her that's gone. Besides, the gods
# Will have fulfill'd their secret purposes;
# For has not the divine Apollo said,
# Is't

# %% [markdown]
# ### Building Our Model
#
# Our model consists of three main components:
#
# 1. [**Embedding**](https://pytorch.org/docs/stable/nn.html#embedding). A mapping between characters and their learned representations ("word vectors") \[correspoding to ${\boldsymbol L}$ in terms of the handout\]
# 2. [**GRU**](https://pytorch.org/docs/stable/nn.html#gru). \[correspoding to the computation of ${\boldsymbol h}^{(t)}$ in terms of the handout\]
# 3. **Output Layer**. A feed-forward neural network that transforms a hidden state at a timestep into a probability distribution of the next character. \[correspoding to the computation of $\hat{\boldsymbol y}^{(t)}$ in terms of the handout\]

# %% [markdown]
# ### Question 3.b
# Complete the implementation of the `forward` method of our model.

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

class OurModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=1):
        super(OurModel, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers

        self.embedding = nn.Embedding(input_size, hidden_size)  # In the terms of the handout, here d = D_h
        self.gru = nn.GRU(hidden_size, hidden_size, num_layers)
        self.output_layer = nn.Linear(hidden_size, output_size)

    def forward(self, input_, hidden):
        # General instructions:
        # Pass the embedded input through the GRU and use the output layer to get the next character distribution.
        # return that distribution and the next hidden state.
        # You may need to play around with the dimensions a bit until you get it right. Dimension-induced frustration is good for you!
        # -------------------------
        # YOUR CODE HERE

        input_embedded = self.embedding(input_).reshape(1, 1, -1)

        _, hidden = self.gru(input_embedded, hidden)

        output = self.output_layer(hidden).reshape(1, self.output_size)

        # -------------------------
        return output, hidden

    def init_hidden(self):
        return Variable(torch.zeros(self.num_layers, 1, self.hidden_size))

# %% [markdown]
# ### Creating the Training Examples

# %% [markdown]
# Each chunk will be turned into a tensor by looping through the characters of the string and looking up the index of each character in `all_characters`.

# %%
# Turn a string into list of longs
def chars_to_tensor(string):
    tensor = torch.zeros(len(string)).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return Variable(tensor)

print(chars_to_tensor('abcDEF'))
# Out:
# tensor([10, 11, 12, 39, 40, 41])

# %% [markdown]
# Now we can assemble a pair of input and target tensors (i.e. a single training example) for training, from a random chunk. The input will be all characters *except the last*, and the target will be all characters *except the first*. So if our chunk is "abc" the input will correspond to "ab" while the target is "bc".

# %%
def random_training_set():
    chunk = random_chunk()
    inp = chars_to_tensor(chunk[:-1])
    target = chars_to_tensor(chunk[1:])
    return inp, target

# %% [markdown]
# ### Evaluating
#
# To evaluate the network we will feed one character at a time, use the outputs of the network as a probability distribution for the next character, and repeat. To start generation we pass a priming string to start building up the hidden state, from which we then generate one character at a time.

# %%
import torch.nn.functional as F

def evaluate(prime_str='A', predict_len=100, temperature=0.8):
    hidden = model.init_hidden()
    prime_input = chars_to_tensor(prime_str)
    predicted = prime_str

    # Use priming string to "build up" hidden state
    for p in range(len(prime_str) - 1):
        _, hidden = model(prime_input[p], hidden)
    inp = prime_input[-1]

    for p in range(predict_len):
        output, hidden = model(inp, hidden)

        # Sample from the network as a multinomial distribution
        output_dist =  F.softmax(output / temperature, dim=-1)
        top_i = torch.multinomial(output_dist, 1)[0]

        # Add predicted character to string and use as next input
        predicted_char = all_characters[top_i]
        predicted += predicted_char
        inp = chars_to_tensor(predicted_char)

    return predicted

# %% [markdown]
# ### Training

# %% [markdown]
# The main training function

# %%
def train(inp, target):
    hidden = model.init_hidden()
    model.zero_grad()
    loss = 0

    for c in range(chunk_len):
        output, hidden = model(inp[c], hidden)
        loss += criterion(output, target[c].view(-1))

    loss.backward()
    optimizer.step()

    return loss.item() / chunk_len

# %% [markdown]
# A helper to print the amount of time passed:

# %%
import time, math

def time_since(since):
    s = time.time() - since
    m = math.floor(s / 60)
    s -= m * 60
    return f'{m}m {math.floor(s)}s'

# %%
# DO NOT DELETE THIS CELL

# %% [markdown]
# Define the training parameters, instantiate the model, and start training:

# %%
n_epochs = 2000
print_every = 100
plot_every = 10
hidden_size = 100  # (D_h from the handout)
num_layers = 1
lr = 0.005

model = OurModel(n_characters, hidden_size, n_characters, num_layers)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

start = time.time()
all_losses = []
loss_avg = 0

for epoch in range(1, n_epochs + 1):
    loss = train(*random_training_set())
    loss_avg += loss

    if epoch % print_every == 0:
        print(f'[time elapsed: {time_since(start)}  ;  epochs: {epoch} ({epoch / n_epochs * 100}%)  ;  loss: {loss:.4}]')
        print(evaluate('Wh', 200), '\n')  # generate text starting with 'Wh'

    if epoch % plot_every == 0:
        all_losses.append(loss_avg / plot_every)
        loss_avg = 0
# Out:
# [time elapsed: 0m 44s  ;  epochs: 100 (5.0%)  ;  loss: 2.287]
# Whaet wore, dith and inie.
# FI, hat ke,
# No mere:
# Tot the thenouers vord a to I fores the are the on berene's boud man ben thatesu fealss the!
#
# Hide,
# Shernines that to beforese om.
#
# ARUTGNINCES:
# Whin bled
#
# [time elapsed: 1m 17s  ;  epochs: 200 (10.0%)  ;  loss: 2.061]
# Wheper mee and parto thell us
# Loth us gon; han that fedelou a do to be Lurd.
# Lelal noth you breat pretce aso my thefe we frother a me musst mo? I and to to that a did yeath pave taste per,
# Te him.
#
# ESOL
#
# [time elapsed: 1m 50s  ;  epochs: 300 (15.0%)  ;  loss: 1.908]
# Whad have buch stay't the we land upping but we dindo. Hado hese, me some pondes:
# Angain the hought she,
# And expone's conher dise rean diders, in sus to during hear sin's as that have as to my brace, a
#
# [time elapsed: 2m 25s  ;  epochs: 400 (20.0%)  ;  loss: 1.786]
# Wher rovend vay's wall it hee stall seem
# Rome is thou commins my Rell.
#
# PEM&ENTI:
# He not so beent bill constal my mysely your ther land were the to vattlue the in turse have ruth he in of he mand, be th
#
# [time elapsed: 2m 58s  ;  epochs: 500 (25.0%)  ;  loss: 1.982]
# Whated
# Freaven doins and arut our you whome, you ble good, fre, flied over;
# The peroth
# And Sise cauon or nothant more good and to To heir to gowanser shother oul here of thy your am be to there to thee
#
# [time elapsed: 3m 31s  ;  epochs: 600 (30.0%)  ;  loss: 2.129]
# Where roght, sing houjpronge? forthe cance,
# What slam
# And sence of fovore hear be fair a crask. He come thee of the by out be we fize that it thee went,
# I such let and as do flous, unconess subean but w
#
# [time elapsed: 4m 4s  ;  epochs: 700 (35.0%)  ;  loss: 1.781]
# Whating mine our such our come in to thich there is that in that doo boon for thy lake strukner marth count the speeosty to earth him,
# And marish lead,
# And as un the Lords,
# And thy do disintuphe,
# Bere t
#
# [time elapsed: 4m 37s  ;  epochs: 800 (40.0%)  ;  loss: 1.752]
# What upposed
# That prorvenger.
# 'Tiff and happlead of Came with fecoriouser is call extlied blered bonds me, arpself inseve speate.
# In not in me dreat.
# How and me kath'st and doth is is loves is complaint
#
# [time elapsed: 5m 9s  ;  epochs: 900 (45.0%)  ;  loss: 1.771]
# What a plandot know roth this did hather thouse his sear and and would Athat,
# And him, therefory she have,
# To baghters. Frothy prokBurt ourses And our cenables fill be me seet
# And much for this appeathe
#
# [time elapsed: 5m 42s  ;  epochs: 1000 (50.0%)  ;  loss: 1.781]
# Whenselmabull by the from the my to prangealo:
# Be gighternt uptooughter am ever rowher the will are you dwission that I now older;
# In all the for that the sweer so should as I say canion lorge, the upin
#
# [time elapsed: 6m 15s  ;  epochs: 1100 (55.00000000000001%)  ;  loss: 1.931]
# Who hude citester's pring sure!
#
# BRUTUS:
# 'A weard with what a pillered that for the can here spick bear will hown,
# And would that to house would frould, a pusin, you ladine and affeds be hear deart your
#
# [time elapsed: 6m 47s  ;  epochs: 1200 (60.0%)  ;  loss: 1.633]
# Which of her and rate kill
# can beard, when marry.
#
# Thich a reefor'd have all it
# To be sill common him our and
# The day though's arm the come not thy not the gready you;
# How he illo: thee his thing suet g
#
# [time elapsed: 7m 20s  ;  epochs: 1300 (65.0%)  ;  loss: 1.895]
# Wherref their my me in bril'd gant but were,
# My most-tell morque I had I was will sway, it consure with me your mence adireves compariarge:
# Now please of him with sentter
# With me suried ray be you: all
#
# [time elapsed: 7m 53s  ;  epochs: 1400 (70.0%)  ;  loss: 1.825]
# What is this mobers my then knowst licker vow not my madm my thymelf;
# That ig holion one my of them moutizens:
# Lest my one, foor the malk my spiendred
# A mace of fing?'
#
# DUKE OF AUMERLE:
# Nor, the as his
#
# [time elapsed: 8m 25s  ;  epochs: 1500 (75.0%)  ;  loss: 1.921]
# Whroner; lemioes of redeouse, and the fool
# Ai' consultal know thought, I from hear heres was noser
# The commoness.
#
# PETRUCHIO: I kill sweet Buclind
# NIUS:
# The heart To't Parten word both our then caser th
#
# [time elapsed: 8m 58s  ;  epochs: 1600 (80.0%)  ;  loss: 1.539]
# Why propt,
# All than there so core and with at it:
# Bway that break nother, the so.
#
# TRANIO:
# Great sweet foor have which want, what I prove my ould,
# Gresines, seal it him grainter,
# As the shoul brivion,
# W
#
# [time elapsed: 9m 30s  ;  epochs: 1700 (85.0%)  ;  loss: 1.589]
# What freat me do there the willl our franes to is daugh say
# Us merance meet is me the shall have
# And Wife my mand'ss thy field no from forld,
# In with my the was him that for thyself the ears.
#
# BRUTUS:
# I
#
# [time elapsed: 10m 3s  ;  epochs: 1800 (90.0%)  ;  loss: 1.614]
# Whrow; and are Englmbus not coursely.
#
# PETRUCHIO:
# Them quee is happy for ereed amon.
#
# Sother, is madal news
# The said bear'st but whould the Maluse,
# Make. death all awigion molamed of Gut the illow:
# He c
#
# [time elapsed: 10m 35s  ;  epochs: 1900 (95.0%)  ;  loss: 1.734]
# What losf the lore
# Mince, my so the some with herous not my maning.
#
# LORD ANE: lady's
# Fit a graves undrantion.
#
# BUCKINGA:
# I caling have and fleperne for the spurniend the
# bled king? Have mebbless her is
#
# [time elapsed: 11m 8s  ;  epochs: 2000 (100.0%)  ;  loss: 1.615]
# Whe the surtake: I condicest
# To very hile: we and then wellant,
# Your her that's his will?
#
# LUCIO:
# Freed of but so king with I'll
# I thee his down unjuctothantt:
# Have good midsitence; my forn
# Bear now lie

# %% [markdown]
# ### Training Loss
#
# Plotting the the losses that were computed during training can provide a further indication that the network was indeed learning (Add your plot to the final submission pdf).

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.grid(True)
plt.xlabel('# of epochs (divided by plot_every)')
plt.ylabel('average loss')
plt.plot(all_losses)

# %%
import numpy as np


def perplexity(text, temprature=0.8):
    sum_of_logs = 0
    hidden = model.init_hidden()
    for i in range(1, len(text)):
        if text[i-1] not in all_characters or text[i] not in all_characters:
          continue
        output, hidden = model(chars_to_tensor(text[i-1]), hidden)
        output_dist = F.softmax(output / temprature, dim=-1)
        index_actual_letter = all_characters.index(text[i])
        prob_actual_letter = output_dist[0, index_actual_letter].item()
        sum_of_logs += np.log2(prob_actual_letter)

    return 2**(-sum_of_logs/len(text))


with open('shakespeare_for_perplexity.txt', 'r') as file:
    print("peprlexity for Shakespeare is: " + str(perplexity(file.read())))

with open('wikipedia_for_perplexity.txt', 'r') as file:
    print("peprlexity for Wikipedia is: " + str(perplexity(file.read())))
# Out:
# peprlexity for Shakespeare is: 7.15222134888849
# peprlexity for Wikipedia is: 18.354485501964916
